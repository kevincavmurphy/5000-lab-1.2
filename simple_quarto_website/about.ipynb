# %% [markdown]
# ---
# title: "About"
# ---
#
# # Kevin's Guide to Business
#
# ## See below

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6]
y = [2, 7, 6, 11, 10, 18]

plt.plot(x, y, marker='o', linestyle='-')

plt.title("Business Strategy")
plt.xlabel("Time (days)")
plt.ylabel("Revenue (million $)")

plt.grid(True)

plt.show()
