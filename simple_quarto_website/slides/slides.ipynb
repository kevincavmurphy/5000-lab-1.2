# %% [raw]
# ---
# title: "Project Deck"
# format:
#   revealjs:
#     theme: simple
#     slide-number: true
#     transition: fade
#     code-fold: true
#     preview-links: false
#     footer: "[← Back to site](../index.html)"
# bibliography: ../reference.bib
# execute:
#   echo: true
#   warning: false
#   message: false
# ---

# %% [markdown]
# ## Overview
#
# Welcome to the demo deck built with **Quarto + reveal.js** inside a Jupyter notebook.
# We outline the typical data science lifecycle and include images, citations, and executable code.
#
# As emphasized in foundational work (see @vaswani2017attention), clear problem framing and measurement are essential.

# %% [markdown]
# ## Visuals
#
# ::: {layout-ncol=2}
# ![](images/img1.jpg){fig-cap="Image One"}
# ![](images/img2.jpg){fig-cap="Image Two"}
# :::

# %%
# Simple line plot demo
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4, 5]
y = [0, 1, 4, 9, 16, 25]

plt.figure(figsize=(6,4))
plt.plot(x, y, marker='o', linestyle='-')
plt.title("Example Plot")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Data Science Process
#
# ```{mermaid}
# flowchart LR
#   A[Define Problem] --> B[Acquire Data]
#   B --> C[EDA]
#   C --> D[Prep/Features]
#   D --> E[Model]
#   E --> F{Good?}
#   F -- Yes --> G[Deploy]
#   F -- No --> C
#   G --> H[Monitor]
#   H --> C
# ```
